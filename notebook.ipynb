# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('boat_data.csv')
data.head()
# Out:
#        Price  ... Number of views last 7 days
# 0   CHF 3337  ...                         226
# 1   EUR 3490  ...                          75
# 2   CHF 3770  ...                         124
# 3  DKK 25900  ...                          64
# 4   EUR 3399  ...                          58
#
# [5 rows x 10 columns]

# %%
data.describe()
# Out:
#         Year Built       Length        Width  Number of views last 7 days
# count  9888.000000  9879.000000  9832.000000                  9888.000000
# mean   1893.192860    11.570017     3.520124                   149.160801
# std     460.201582     6.002820     1.220534                   151.819752
# min       0.000000     1.040000     0.010000                    13.000000
# 25%    1996.000000     7.470000     2.540000                    70.000000
# 50%    2007.000000    10.280000     3.330000                   108.000000
# 75%    2017.000000    13.930000     4.250000                   172.000000
# max    2021.000000   100.000000    25.160000                  3263.000000

# %%
data.isna().sum()
# Out:
# Price                             0
# Boat Type                         0
# Manufacturer                   1338
# Type                              6
# Year Built                        0
# Length                            9
# Width                            56
# Material                       1749
# Location                         36
# Number of views last 7 days       0
# dtype: int64

# %%
data.dropna(inplace=True)
data.describe()
# Out:
#         Year Built       Length        Width  Number of views last 7 days
# count  7019.000000  7019.000000  7019.000000                  7019.000000
# mean   1883.852543    11.036492     3.433109                   159.909104
# std     481.441089     5.144034     1.119766                   167.153110
# min       0.000000     1.980000     0.860000                    13.000000
# 25%    1998.000000     7.280000     2.540000                    72.000000
# 50%    2008.000000     9.950000     3.200000                   112.000000
# 75%    2018.000000    13.500000     4.180000                   185.000000
# max    2021.000000    56.000000    16.000000                  3263.000000

# %%
data.rename(columns={'Number of views last 7 days':'Views'},inplace=True)
data.columns
# Out:
# Index(['Price', 'Boat Type', 'Manufacturer', 'Type', 'Year Built', 'Length',
#        'Width', 'Material', 'Location', 'Views'],
#       dtype='object')

# %%
data.sort_values('Views',ascending=False)
# Out:
#            Price  ... Views
# 9580   CHF 14900  ...  3263
# 8723   CHF 35000  ...  2432
# 6211  CHF 125900  ...  2261
# 3700  EUR 949000  ...  2154
# 308    CHF 19900  ...  2026
# ...          ...  ...   ...
# 7138   EUR 70000  ...    19
# 7458   EUR 62800  ...    18
# 2517   Â£ 229950  ...    18
# 7800   EUR 53900  ...    15
# 3982  EUR 580000  ...    13
#
# [7019 rows x 10 columns]

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(data=data)
# Out:
# <AxesSubplot: >

# %%
price=data[['Price','Views']]
boat_type=data[['Boat Type','Views']]
manufacturer=data[['Manufacturer','Views']]
type_1=data[['Type','Views']]
year=data[['Year Built','Views']]
dimensions=data[['Length','Width','Views']]
material=data[['Material','Views']]
location=data[['Location','Views']]
#['Price', 'Boat Type', 'Manufacturer', 'Type', 'Year Built', 'Length','Width', 'Material', 'Location', 'Views']

# %%
new=data[data['Views']>1000]
print(new)
# Out:
#            Price  ... Views
# 35      CHF 3800  ...  1804
# 57      CHF 7200  ...  1201
# 153    EUR 12000  ...  1101
# 280    CHF 19500  ...  1028
# 308    CHF 19900  ...  2026
# 462    CHF 28000  ...  1136
# 593    CHF 33000  ...  1033
# 894    CHF 48500  ...  1970
# 1278   CHF 69000  ...  1019
# 1625   CHF 95000  ...  1319
# 1654   EUR 89900  ...  1014
# 1848  CHF 119000  ...  1414
# 2029  EUR 139000  ...  1621
# 2348  EUR 199999  ...  1230
# 2420  EUR 220000  ...  1153
# 3700  EUR 949000  ...  2154
# 4510  EUR 339000  ...  1461
# 4548  CHF 350000  ...  1780
# 4804  CHF 295000  ...  1107
# 5216  EUR 209000  ...  1700
# 5643  EUR 159359  ...  1710
# 6211  CHF 125900  ...  2261
# 7379   EUR 65000  ...  1119
# 7749   CHF 59000  ...  1054
# 7859   CHF 55000  ...  1386
# 8087   CHF 50000  ...  1017
# 8092   EUR 46000  ...  1019
# 8505   EUR 37625  ...  1272
# 8517   EUR 37500  ...  1128
# 8520   EUR 37000  ...  1351
# 8684   CHF 36000  ...  1834
# 8723   CHF 35000  ...  2432
# ...
